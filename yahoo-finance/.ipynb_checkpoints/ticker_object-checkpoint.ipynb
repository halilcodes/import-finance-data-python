# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = 'DIS'

# %%
dis = yf.Ticker(ticker)

# %%
dis
# Out:
# yfinance.Ticker object <DIS>

# %%
dis.ticker
# Out:
# 'DIS'

# %%
methods = [m for m in dir(dis) if '__' not in m]
methods
# Out:
# ['_analysis',
#  '_base_url',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fix_bad_stock_split',
#  '_fix_missing_div_adjust',
#  '_fix_prices_sudden_change',
#  '_fix_unit_mixups',
#  '_fix_unit_random_mixups',
#  '_fix_unit_switch',
#  '_fix_zeroes',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_history',
#  '_history_metadata',
#  '_history_metadata_formatted',
#  '_holders',
#  '_isin',
#  '_news',
#  '_options2df',
#  '_quote',
#  '_reconstruct_intervals_batch',
#  '_reconstruct_start_interval',
#  '_shares',
#  '_tz',
#  '_underlying',
#  'actions',
#  'analyst_price_target',
#  'balance_sheet',
#  'balancesheet',
#  'basic_info',
#  'calendar',
#  'capital_gains',
#  'cash_flow',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'earnings_dates',
#  'earnings_forecasts',
#  'earnings_trend',
#  'fast_info',
#  'financials',
#  'get_actions',
# ...

# %%
dis.splits
# Out:
# Date
# 1962-12-18 00:00:00-05:00    1.030000
# 1967-11-16 00:00:00-05:00    2.000000
# 1971-03-01 00:00:00-05:00    2.000000
# 1973-01-16 00:00:00-05:00    2.000000
# 1986-03-06 00:00:00-05:00    4.000000
# 1992-05-18 00:00:00-04:00    4.000000
# 1998-07-10 00:00:00-04:00    3.000000
# 2007-06-13 00:00:00-04:00    1.013685
# Name: Stock Splits, dtype: float64

# %%
dis.info
# Out:
# {'address1': '500 South Buena Vista Street',
#  'city': 'Burbank',
#  'state': 'CA',
#  'zip': '91521',
#  'country': 'United States',
#  'phone': '818 560 1000',
#  'website': 'https://www.thewaltdisneycompany.com',
#  'industry': 'Entertainment',
#  'industryDisp': 'Entertainment',
#  'sector': 'Communication Services',
#  'sectorDisp': 'Communication Services',
# ...

# %%
dis.options
# Out:
# ('2023-08-25',
#  '2023-09-01',
#  '2023-09-08',
#  '2023-09-15',
#  '2023-09-22',
#  '2023-09-29',
#  '2023-10-06',
#  '2023-10-20',
#  '2023-11-17',
#  '2023-12-15',
#  '2024-01-19',
#  '2024-03-15',
#  '2024-04-19',
#  '2024-06-21',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
dis.get_cashflow()
# Out:
#                                        2022-09-30    2021-09-30  \
# FreeCashFlow                         1067000000.0  1989000000.0
# RepurchaseOfCapitalStock                      NaN           NaN
# RepaymentOfDebt                     -4016000000.0 -3737000000.0
# IssuanceOfDebt                        333000000.0    64000000.0
# CapitalExpenditure                  -4943000000.0 -3578000000.0
# ...                                           ...           ...
# PensionAndEmployeeBenefitExpense      620000000.0   816000000.0
# EarningsLossesFromEquityInvestments  -816000000.0  -761000000.0
# GainLossOnInvestmentSecurities        714000000.0  -332000000.0
# GainLossOnSaleOfBusiness                      NaN           NaN
# NetIncomeFromContinuingOperations    3553000000.0  2536000000.0
#
#                                         2020-09-30     2019-09-30
# FreeCashFlow                          3596000000.0   1730000000.0
# ...

# %%
dis.history()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-07-25 00:00:00-04:00  85.730003  86.309998  85.160004  85.629997
# 2023-07-26 00:00:00-04:00  85.669998  86.269997  85.449997  85.860001
# 2023-07-27 00:00:00-04:00  86.599998  86.879997  85.190002  85.360001
# 2023-07-28 00:00:00-04:00  85.860001  86.580002  85.449997  86.129997
# 2023-07-31 00:00:00-04:00  87.000000  89.360001  86.879997  88.889999
# 2023-08-01 00:00:00-04:00  89.120003  89.730003  88.459999  89.029999
# 2023-08-02 00:00:00-04:00  88.260002  88.330002  86.260002  86.300003
# 2023-08-03 00:00:00-04:00  85.820000  86.459999  85.449997  85.489998
# 2023-08-04 00:00:00-04:00  85.940002  87.110001  85.449997  86.300003
# 2023-08-07 00:00:00-04:00  86.660004  87.230003  85.989998  86.830002
# 2023-08-08 00:00:00-04:00  86.500000  88.330002  86.099998  88.129997
# 2023-08-09 00:00:00-04:00  89.199997  89.559998  87.040001  87.489998
# ...
