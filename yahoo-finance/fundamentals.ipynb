# %% [markdown]
# # fundamentals, metadata, performance metrics

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = 'DIS'

# %%
dis = yf.Ticker(ticker)

# %%
dis.info
# Out:
# {'address1': '500 South Buena Vista Street',
#  'city': 'Burbank',
#  'state': 'CA',
#  'zip': '91521',
#  'country': 'United States',
#  'phone': '818 560 1000',
#  'website': 'https://www.thewaltdisneycompany.com',
#  'industry': 'Entertainment',
#  'industryDisp': 'Entertainment',
#  'sector': 'Communication Services',
#  'sectorDisp': 'Communication Services',
# ...

# %%
pd.Series(dis.info)
# Out:
# address1             500 South Buena Vista Street
# city                                      Burbank
# state                                          CA
# zip                                         91521
# country                             United States
#                                  ...
# grossMargins                              0.32772
# ebitdaMargins                             0.14807
# operatingMargins                          0.08798
# financialCurrency                             USD
# trailingPegRatio                           0.7441
# Length: 125, dtype: object

# %%
df = pd.Series(dis.info, name='DIS').to_frame().T
df
# Out:
#                          address1     city state    zip        country  \
# DIS  500 South Buena Vista Street  Burbank    CA  91521  United States
#
#             phone                               website       industry  \
# DIS  818 560 1000  https://www.thewaltdisneycompany.com  Entertainment
#
#       industryDisp                  sector  ... returnOnEquity grossProfits  \
# DIS  Entertainment  Communication Services  ...        0.02721  28321000000
#
#     freeCashflow operatingCashflow revenueGrowth grossMargins ebitdaMargins  \
# DIS   5497874944        7587999744         0.038      0.32772       0.14807
#
#     operatingMargins financialCurrency trailingPegRatio
# DIS          0.08798               USD           0.7441
#
# [1 rows x 125 columns]

# %%
ticker = ["MSFT", "META"]

# %%
for i in ticker:
    df.loc["{}".format(i)] = pd.Series(yf.Ticker(i).info)

# %%
df['companyOfficers']['DIS']
# Out:
# [{'maxAge': 1,
#   'name': 'Mr. Robert A. Iger',
#   'age': 71,
#   'title': 'CEO & Director',
#   'yearBorn': 1951,
#   'fiscalYear': 2022,
#   'totalPay': 11268271,
#   'exercisedValue': 34866408,
#   'unexercisedValue': 778341},
#  {'maxAge': 1,
#   'name': 'Mr. Horacio E. Gutierrez',
#   'age': 57,
#   'title': 'Sr. EVP & Gen. Counsel',
#   'yearBorn': 1965,
#   'fiscalYear': 2022,
#   'totalPay': 6746194,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Ms. Kristina K. Schake',
#   'age': 51,
#   'title': 'Sr. EVP & Chief Communications Officer',
#   'yearBorn': 1971,
#   'fiscalYear': 2022,
#   'totalPay': 3186694,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. Kevin  Lansberry',
#   'age': 58,
#   'title': 'Interim Chief Financial Officer',
#   'yearBorn': 1964,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Ms. Diane  Jurgens M.B.A., BSEE, MSEE, MBA',
#   'age': 60,
# ...

# %%
df.columns
# Out:
# Index(['address1', 'city', 'state', 'zip', 'country', 'phone', 'website',
#        'industry', 'industryDisp', 'sector',
#        ...
#        'returnOnEquity', 'grossProfits', 'freeCashflow', 'operatingCashflow',
#        'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins',
#        'financialCurrency', 'trailingPegRatio'],
#       dtype='object', length=125)

# %% [markdown]
# # download financials

# %%
dis
# Out:
# yfinance.Ticker object <DIS>

# %%
dis.balance_sheet
# Out:
#                                                      2022-09-30  \
# Treasury Shares Number                               19000000.0
# Ordinary Shares Number                             1781000000.0
# Share Issued                                       1800000000.0
# Net Debt                                          36754000000.0
# Total Debt                                        48369000000.0
# ...                                                         ...
# Receivables Adjustments Allowances                 -158000000.0
# Other Receivables                                  1999000000.0
# Accounts Receivable                               12652000000.0
# Cash Cash Equivalents And Short Term Investments  11615000000.0
# Cash And Cash Equivalents                         11615000000.0
#
#                                                      2021-09-30  \
# Treasury Shares Number                               19000000.0
# Ordinary Shares Number                             1818000000.0
# ...

# %%
dis.financials
# Out:
#                                                           2022-09-30  \
# Tax Effect Of Unusual Items                          -77669631.03122
# Tax Rate For Calcs                                           0.32772
# Normalized EBITDA                                      12082000000.0
# Total Unusual Items                                     -237000000.0
# Total Unusual Items Excluding Goodwill                  -237000000.0
# Net Income From Continuing Operation Net Minori...      3193000000.0
# Reconciled Depreciation                                 5163000000.0
# Reconciled Cost Of Revenue                             75952000000.0
# EBIT                                                    6682000000.0
# Net Interest Income                                    -1397000000.0
# Interest Expense                                        1397000000.0
# Interest Income                                          152000000.0
# Normalized Income                                   3352330368.96878
# ...

# %%
dis.income_stmt
# Out:
#                                                           2022-09-30  \
# Tax Effect Of Unusual Items                          -77669631.03122
# Tax Rate For Calcs                                           0.32772
# Normalized EBITDA                                      12082000000.0
# Total Unusual Items                                     -237000000.0
# Total Unusual Items Excluding Goodwill                  -237000000.0
# Net Income From Continuing Operation Net Minori...      3193000000.0
# Reconciled Depreciation                                 5163000000.0
# Reconciled Cost Of Revenue                             75952000000.0
# EBIT                                                    6682000000.0
# Net Interest Income                                    -1397000000.0
# Interest Expense                                        1397000000.0
# Interest Income                                          152000000.0
# Normalized Income                                   3352330368.96878
# ...

# %%
tickers = ['DIS', 'TSLA', 'AMZN', 'META']

# %%
# for symbol in tickers:
#     yf.Ticker(symbol).financials.to_excel(f"files/{symbol}_info.xlsx", engine='openpyxl')
